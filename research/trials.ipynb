# %%
#config box

d = {"key":"val"}

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"val2","key3":"val3"})

# %%
d2.key
# Out:
# 'val2'

# %%
pip install beartype
# Out:
# ...
#   Using cached beartype-0.22.5-py3-none-any.whl.metadata (36 kB)
# Using cached beartype-0.22.5-py3-none-any.whl (1.3 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from beartype import beartype

# %%
@beartype
def get_add(a: int, b: int) -> int:
    return a + b

# %%
get_add(a=2, b=3)
# Out:
# 5

# %%
get_add(a=2, b="3")
# Out:
# ---------------------------------------------------------------------------
# BeartypeCallHintParamViolation            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 get_add(a=2, b="3")
#
# File <@beartype(__main__.get_add) at 0x10a842ca0>:46, in get_add(__beartype_get_violation, __beartype_conf, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# BeartypeCallHintParamViolation: Function __main__.get_add() parameter b='3' violates type hint <class 'int'>, as str '3' not instance of int.
